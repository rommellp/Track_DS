# %%
#import modules for analyzing ,plotting, and formatting
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
import seaborn as sns

# %%
original_tf_data = pd.read_csv("first_upload.csv")

df = pd.DataFrame(original_tf_data, columns=['ID Number','Gender','Grade Level','Season','400 Meters','800 Meters','1500 Meters','1600 Meters'])
columnsTitles = ['ID Number','Gender','Grade Level','Season','400 Meters','800 Meters','1500 Meters','1600 Meters']
original_tf_df = df.reindex(columns=columnsTitles)

original_tf_df
copy_df = original_tf_df.copy()

# %%
copy_df
# Out:
#        ID Number Gender Grade Level                                    Season  \
# 0             21      M  12th Grade  2007 Outdoor Season
# 1             21      M  12th Grade  2007 Outdoor Season
# 2             21      M  12th Grade  2007 Outdoor Season
# 3             21      M  12th Grade  2007 Outdoor Season
# 4             21      M  12th Grade  2007 Outdoor Season
# ...          ...    ...         ...                                       ...
# 41784      19989      M  12th Grade  2005 Outdoor Season
# 41785      19991      M  12th Grade  2005 Outdoor Season
# 41786      19991      M  12th Grade  2005 Outdoor Season
# 41787      19991      M  12th Grade  2005 Outdoor Season
# 41788      19991      M  12th Grade  2005 Outdoor Season
#
#       400 Meters 800 Meters 1500 Meters 1600 Meters
# 0          57.74        NaN         NaN         NaN
# 1         57.34c        NaN         NaN         NaN
# 2         56.14c        NaN         NaN         NaN
# 3          57.2h        NaN         NaN         NaN
# 4          58.8h        NaN         NaN         NaN
# ...          ...        ...         ...         ...
# 41784     54.14c        NaN         NaN         NaN
# 41785        NaN    3:27.3h         NaN         NaN
# 41786        NaN    3:14.3h         NaN         NaN
# 41787        NaN    3:21.5h         NaN         NaN
# 41788        NaN    3:05.3h         NaN         NaN
#
# [41789 rows x 8 columns]

# %%
copy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41789 entries, 0 to 41788
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID Number    41789 non-null  int64
#  1   Gender       41789 non-null  object
#  2   Grade Level  41789 non-null  object
#  3   Season       41789 non-null  object
#  4   400 Meters   14362 non-null  object
#  5   800 Meters   12910 non-null  object
#  6   1500 Meters  14315 non-null  object
#  7   1600 Meters  200 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 2.6+ MB

# %%
# this is the laters version of these def I am running

null_times = {np.nan,'nan','DNR','nt','no time','FS','DQ','NT','SCR','DNS','DNF','na','MB', 'shot 29.9', 'NS', '?'}

def time_convert(x):
    if (str(x)[-1]=='c') or (str(x)[-1]=='h'):
        x = str(x)[:-1] 
    x_split = str(x).split(':')
    if not '.' in x_split[-1]:
        x = str(x) + '.00'
    #print(x)
    ##Annoying edge cases
    if (x_split[-1] == '60.00') or (x_split[-1] =='60.0') or (x_split[-1] == '28/0'):
      #print('here')
      return np.nan

    if (x[-1] == 'a'):
      #print('here')
      return(np.nan)

    if (str(x) == '57.4**'):
      #print(x)
      return(np.nan)

    if len(x_split)==1:
        t = datetime.datetime.strptime(x, '%S.%f').time()
        return((t.hour * 60 + t.minute) *60 + t.second+ 0.000001*t.microsecond)

    if len(x_split)==2:
      t = datetime.datetime.strptime(x, '%M:%S.%f').time()
      return((t.hour * 60 + t.minute) *60 + t.second+ 0.000001*t.microsecond)

    if len(x_split)==3:
        t = datetime.datetime.strptime(x, '%H:%M:%S.%f').time()
        return((t.hour * 60 + t.minute) *60 + t.second+ 0.000001*t.microsecond)

# %%
#One dataframe for each event
#here we are doing the final filtering of these df's
#by using a list of wrongly input features, we can check if those values are in any 
#row of these 400m cols. if it is, it is filtered out using the '~'. 
#finally, convert time is applied to convert each input time to seconds. 

df_400 = copy_df[['ID Number', 'Gender', 'Grade Level', 'Season', '400 Meters']]
df_400 = df_400[~df_400['400 Meters'].isin(null_times)]
df_400['400 Meters'] = df_400['400 Meters'].apply(time_convert)

df_800 = copy_df[['ID Number', 'Gender', 'Grade Level', 'Season', '800 Meters']]
df_800 = df_800[~df_800['800 Meters'].isin(null_times)]
df_800['800 Meters'] = df_800['800 Meters'].apply(time_convert)

df_1500 = copy_df[['ID Number', 'Gender', 'Grade Level', 'Season', '1500 Meters']]
df_1500 = df_1500[~df_1500['1500 Meters'].isin(null_times)]
df_1500['1500 Meters'] = df_1500['1500 Meters'].apply(time_convert)

df_1600 = copy_df[['ID Number', 'Gender', 'Grade Level', 'Season', '1600 Meters']]
df_1600 = df_1600[~df_1600['1600 Meters'].isin(null_times)]

df_1600['1600 Meters'] = df_1600['1600 Meters'].apply(time_convert)

# %%
df_1600.info()
df_1600[(df_1600['1600 Meters']>500) | (df_1600['1600 Meters']<100)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196 entries, 158 to 41559
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID Number    196 non-null    int64
#  1   Gender       196 non-null    object
#  2   Grade Level  196 non-null    object
#  3   Season       196 non-null    object
#  4   1600 Meters  195 non-null    float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 9.2+ KB
#        ID Number Gender Grade Level                                    Season  \
# 5324        2325      M  11th Grade  2005 Outdoor Season
# 5341        2326      M  10th Grade  2005 Outdoor Season
# 5356        2328      M  12th Grade  2005 Outdoor Season
# 5418        2329      M  10th Grade  2005 Outdoor Season
# 5437        2331      M  12th Grade  2005 Outdoor Season
# 14911       6342      M  12th Grade  2004 Outdoor Season
# 14940       6344      M  12th Grade  2004 Outdoor Season
# 14958       6345      M  12th Grade  2004 Outdoor Season
# 15014       6346      M  10th Grade  2004 Outdoor Season
# 16508       7083      M  10th Grade  2004 Outdoor Season
# 17688       7805      M  11th Grade  2005 Outdoor Season
# 41559      19803      M  11th Grade  2005 Outdoor Season
#
#        1600 Meters
# 5324          57.8
# 5341          56.3
# 5356          56.6
# 5418          55.6
# 5437          57.6
# 14911         53.0
# 14940         56.0
# 14958         54.0
# 15014         56.0
# 16508          5.0
# 17688         57.4
# 41559         57.1

# %%
df_1500.info()
df_1500[(df_1500['1500 Meters']>500) | (df_1500['1500 Meters']<100)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14195 entries, 72 to 41777
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID Number    14195 non-null  int64
#  1   Gender       14195 non-null  object
#  2   Grade Level  14195 non-null  object
#  3   Season       14195 non-null  object
#  4   1500 Meters  14188 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 665.4+ KB
#        ID Number Gender Grade Level                                    Season  \
# 971          652      M   9th Grade  2004 Outdoor Season
# 1303         726      M  11th Grade  2004 Outdoor Season
# 4260        1727      M  12th Grade  2004 Outdoor Season
# 5448        2336      M   9th Grade  2004 Outdoor Season
# 10224       4204      M   9th Grade  2004 Outdoor Season
# 14035       5891      M   9th Grade  2004 Outdoor Season
# 16730       7349      M   9th Grade  2004 Outdoor Season
# 16783       7400      M  12th Grade  2005 Outdoor Season
# 18023       8086      M  12th Grade  2007 Outdoor Season
# 18650       8501      M  12th Grade  2004 Outdoor Season
# 21126      10335      M  10th Grade  2006 Outdoor Season
# 22932      11161      M   9th Grade  2005 Outdoor Season
# 25235      11841      M  12th Grade  2007 Outdoor Season
# 33005      15066      M   9th Grade  2005 Outdoor Season
# 33744      15430      M  11th Grade  2005 Outdoor Season
# 34386      15700      M  10th Grade  2005 Outdoor Season
# 40877      19284      M  11th Grade  2005 Outdoor Season
# 40883      19315      M  10th Grade  2005 Outdoor Season
#
#        1500 Meters
# 971         815.70
# 1303        579.54
# 4260        534.20
# 5448        534.30
# 10224      1666.00
# 14035         0.00
# 16730       616.50
# 16783        61.70
# 18023       509.60
# 18650       571.00
# 21126       906.00
# 22932       801.80
# 25235         0.00
# 33005       628.35
# 33744      4366.00
# 34386       627.29
# 40877       512.10
# 40883       513.10

# %%
df_800.info()
df_800[(df_800['800 Meters']>250) | (df_800['800 Meters']<50)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12783 entries, 12 to 41788
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID Number    12783 non-null  int64
#  1   Gender       12783 non-null  object
#  2   Grade Level  12783 non-null  object
#  3   Season       12783 non-null  object
#  4   800 Meters   12782 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 599.2+ KB
#        ID Number Gender Grade Level                                    Season  \
# 1081         690      M  12th Grade  2004 Outdoor Season
# 4428        1845      M   9th Grade  2004 Outdoor Season
# 10182       4193      M  11th Grade  2005 Outdoor Season
# 18712       8547      M  12th Grade  2008 Outdoor Season
# 18957       8669      M  10th Grade  2004 Outdoor Season
# 19358       8988      M  12th Grade  2005 Outdoor Season
# 19359       8988      M  12th Grade  2005 Outdoor Season
# 19360       8988      M  12th Grade  2005 Outdoor Season
# 19485       9103      M   9th Grade  2004 Outdoor Season
# 21124      10335      M  10th Grade  2006 Outdoor Season
# 21632      10822      M  10th Grade  2005 Outdoor Season
# 25231      11841      M  12th Grade  2007 Outdoor Season
# 25250      11842      M  12th Grade  2007 Outdoor Season
# 26959      12622      M  11th Grade  2005 Outdoor Season
# 30742      14288      M  11th Grade  2005 Outdoor Season
# 31005      14379      M   9th Grade  2005 Outdoor Season
# 32105      14845      M   9th Grade  2005 Outdoor Season
# 38552      17598      M  10th Grade  2006 Outdoor Season
# 40734      19128      M   9th Grade  2005 Outdoor Season
#
#        800 Meters
# 1081       325.30
# 4428       385.12
# 10182     1322.00
# 18712      266.90
# 18957      382.00
# 19358      268.90
# 19359      261.34
# 19360      276.13
# 19485     3178.00
# 21124      750.60
# 21632      746.40
# 25231        0.00
# 25250        0.00
# 26959     1880.00
# 30742       24.80
# 31005      300.00
# 32105      255.00
# 38552      252.40
# 40734     1357.60

# %%
df_400.info()
#There is something wrong with these 15 out of 14k in how their times were reported
df_400[(df_400['400 Meters']>180) | (df_400['400 Meters']<40)]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14223 entries, 0 to 41784
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ID Number    14223 non-null  int64
#  1   Gender       14223 non-null  object
#  2   Grade Level  14223 non-null  object
#  3   Season       14223 non-null  object
#  4   400 Meters   14188 non-null  float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 666.7+ KB
#        ID Number Gender Grade Level                                    Season  \
# 8570        3580      M  11th Grade  2005 Outdoor Season
# 10159       4193      M  12th Grade  2006 Outdoor Season
# 15147       6416      M  12th Grade  2005 Outdoor Season
# 15543       6657      M   9th Grade  2004 Outdoor Season
# 16189       6988      M   9th Grade  2004 Outdoor Season
# 16190       6988      M   9th Grade  2004 Outdoor Season
# 18396       8322      M  10th Grade  2004 Outdoor Season
# 18974       8676      M  11th Grade  2005 Outdoor Season
# 26686      12583      M  11th Grade  2007 Outdoor Season
# 27009      12633      M   9th Grade  2005 Outdoor Season
# 33792      15477      M  11th Grade  2007 Outdoor Season
# 36969      17034      M   9th Grade  2005 Outdoor Season
# 38944      17988      M  10th Grade  2006 Outdoor Season
# 39293      18161      M  11th Grade  2005 Outdoor Season
# 39590      18457      M   9th Grade  2005 Outdoor Season
#
#        400 Meters
# 8570      3304.00
# 10159     3213.14
# 15147     3694.14
# 15543     3573.00
# 16189     3375.14
# 16190     3429.14
# 18396       12.24
# 18974     5775.14
# 26686     3309.00
# 27009     3574.14
# 33792     3268.14
# 36969     3486.14
# 38944       18.74
# 39293     3214.00
# 39590     3548.14

# %% [markdown]
# To analyze this dataset, we will be looking at how the runners have changed over time. Specifically we will answer the questions:
# 1. how has the pop of runners changed over the seasons.
# 2. how has their performance changed( min, max, mean) by season.
# 3. how does a 9th grader perform in a recent season vs one in the earliest season.

# %%
df_15= df_1500[(df_1500['1500 Meters']<500) & (df_1500['1500 Meters']>100)].dropna()
df_15.head()
# Out:
#     ID Number Gender Grade Level                                    Season  \
# 72         63      M  12th Grade  2005 Outdoor Season
# 73         63      M  12th Grade  2005 Outdoor Season
# 74         63      M  12th Grade  2005 Outdoor Season
# 75         63      M  12th Grade  2005 Outdoor Season
# 92         63      M  11th Grade  2004 Outdoor Season
#
#     1500 Meters
# 72       291.40
# 73       267.37
# 74       267.40
# 75       261.68
# 92       265.00

# %%
df_15.shape
# Out:
# (14170, 5)

# %%
df_15["Season"] = df_15["Season"].str.strip()  # strip leading/trailing whitespace

# check the unique values in the "Season" column again
print(df_15["Season"].unique())
# Out:
# ['2005 Outdoor Season' '2004 Outdoor Season' '2003 Outdoor  Season'
#  '2002 Outdoor  Season' '1998 Outdoor  Season' '1997 Outdoor  Season'
#  '1996 Outdoor  Season' '2006 Outdoor Season' '2001 Outdoor  Season'
#  '2000 Outdoor  Season' '1999 Outdoor  Season' '2011 Outdoor Season'
#  '1995 Outdoor  Season' '1994 Outdoor  Season' '2007 Outdoor Season'
#  '2007 Indoor Season' '2009 Outdoor Season' '2008 Outdoor Season'
#  '2004 Indoor Season' '2006 Indoor Season' '2010 Outdoor Season']

# %%
print(df_15['Season'].unique())
# Out:
# ['2005 Outdoor Season' '2004 Outdoor Season' '2003 Outdoor  Season'
#  '2002 Outdoor  Season' '1998 Outdoor  Season' '1997 Outdoor  Season'
#  '1996 Outdoor  Season' '2006 Outdoor Season' '2001 Outdoor  Season'
#  '2000 Outdoor  Season' '1999 Outdoor  Season' '2011 Outdoor Season'
#  '1995 Outdoor  Season' '1994 Outdoor  Season' '2007 Outdoor Season'
#  '2007 Indoor Season' '2009 Outdoor Season' '2008 Outdoor Season'
#  '2004 Indoor Season' '2006 Indoor Season' '2010 Outdoor Season']

# %%
pd.set_option("display.max_rows", None)   # show all rows
pd.set_option("display.max_columns", None)  # show all columns

pop = df_15.groupby(['Season', 'Grade Level'])['ID Number'].nunique()
print(pop)
# Out:
# Season                Grade Level
# 1994 Outdoor  Season  9th Grade        1
# 1995 Outdoor  Season  10th Grade       2
#                       9th Grade        1
# 1996 Outdoor  Season  10th Grade       1
#                       11th Grade       1
#                       9th Grade        2
# 1997 Outdoor  Season  10th Grade       1
#                       11th Grade       2
#                       12th Grade       1
#                       9th Grade        1
# 1998 Outdoor  Season  10th Grade       1
#                       11th Grade       1
# 1999 Outdoor  Season  11th Grade       1
#                       9th Grade        1
# 2000 Outdoor  Season  10th Grade       1
#                       12th Grade       1
# 2001 Outdoor  Season  12th Grade       1
#                       9th Grade        9
# 2002 Outdoor  Season  10th Grade       8
#                       11th Grade       1
#                       9th Grade       17
# 2003 Outdoor  Season  10th Grade      27
#                       11th Grade      28
#                       9th Grade       16
# 2004 Indoor Season    12th Grade       3
# 2004 Outdoor Season   10th Grade     225
#                       11th Grade     248
#                       12th Grade     206
#                       9th Grade      250
#                       ?                1
# 2005 Outdoor Season   10th Grade     344
#                       11th Grade     304
#                       12th Grade     287
#                       8th Grade        1
#                       9th Grade      391
#                       ?                7
# 2006 Indoor Season    10th Grade       1
# 2006 Outdoor Season   10th Grade     289
#                       11th Grade     259
#                       12th Grade     210
#                       9th Grade        7
# 2007 Indoor Season    12th Grade       1
# 2007 Outdoor Season   10th Grade       7
#                       11th Grade     204
#                       12th Grade     188
#                       9th Grade        1
# 2008 Outdoor Season   10th Grade       1
#                       11th Grade       2
#                       12th Grade     164
#                       9th Grade        1
#                       ?                1
# 2009 Outdoor Season   11th Grade       1
#                       12th Grade       4
# 2010 Outdoor Season   12th Grade       1
#                       9th Grade        1
# 2011 Outdoor Season   10th Grade       1
#                       ?                1
# Name: ID Number, dtype: int64

# %% [markdown]
# From the output above we can see that the data is sparse. This tells us that all the columns will not be especially informative. But, we see that the outdoor season for years 2004, 2005, 2006 and maybe 2007 will give us accurate representation for each grade level.
#
# Because we are only looking at these 4 years, I will index for these seasons so the outputs are more clear.

# %%
min_df = df_15[(df_15['Season'] >= '2004 Outdoor Season') & (df_15['Season'] <= '2007 Outdoor Season')]
min_df.head()
# Out:
#     ID Number Gender Grade Level               Season  1500 Meters
# 72         63      M  12th Grade  2005 Outdoor Season       291.40
# 73         63      M  12th Grade  2005 Outdoor Season       267.37
# 74         63      M  12th Grade  2005 Outdoor Season       267.40
# 75         63      M  12th Grade  2005 Outdoor Season       261.68
# 92         63      M  11th Grade  2004 Outdoor Season       265.00

# %%
out = min_df[min_df['Grade Level'] == '?'].index
min_df.drop(index=(out), inplace=True)
# Out:
# <ipython-input-17-c9c0d1dbff97>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_df.drop(index=(out), inplace=True)

# %%
in_05 = min_df[min_df['Season'] == '2005 Indoor Season'].index
in_06 = min_df[min_df['Season'] == '2006 Indoor Season'].index
in_07 = min_df[min_df['Season'] == '2007 Indoor Season'].index

min_df.drop(index=(in_05), inplace=True)
min_df.drop(index=(in_06), inplace=True)
min_df.drop(index=(in_07), inplace=True)
# Out:
# <ipython-input-18-880a71f56c52>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_df.drop(index=(in_05), inplace=True)
# <ipython-input-18-880a71f56c52>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_df.drop(index=(in_06), inplace=True)
# <ipython-input-18-880a71f56c52>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_df.drop(index=(in_07), inplace=True)

# %%
gr_7 = min_df[min_df['Grade Level'] == '7th Grade'].index
gr_8 = min_df[min_df['Grade Level'] == '8th Grade'].index

min_df.drop(index=(gr_7), inplace=True)
min_df.drop(index=(gr_8), inplace=True)
# Out:
# <ipython-input-19-d3e7eaadabdf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_df.drop(index=(gr_7), inplace=True)
# <ipython-input-19-d3e7eaadabdf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   min_df.drop(index=(gr_8), inplace=True)

# %%
pop_min = min_df.groupby(['Season', 'Grade Level'])['ID Number'].nunique()
print(pop_min)
# Out:
# Season               Grade Level
# 2004 Outdoor Season  10th Grade     225
#                      11th Grade     248
#                      12th Grade     206
#                      9th Grade      250
# 2005 Outdoor Season  10th Grade     344
#                      11th Grade     304
#                      12th Grade     287
#                      9th Grade      391
# 2006 Outdoor Season  10th Grade     289
#                      11th Grade     259
#                      12th Grade     210
#                      9th Grade        7
# 2007 Outdoor Season  10th Grade       7
#                      11th Grade     204
#                      12th Grade     188
#                      9th Grade        1
# Name: ID Number, dtype: int64

# %% [markdown]
# Figure 1. Number of unique counts of 1500m runners.

# %%
min_df.shape
# Out:
# (13149, 5)

# %%
season_sort = min_df.groupby(['Grade Level', 'Season']).agg({'1500 Meters': 'mean'}).sort_values(by=['Season', 'Grade Level'], ascending = True)
season_sort
# Out:
#                                  1500 Meters
# Grade Level Season
# 10th Grade  2004 Outdoor Season   298.388028
# 11th Grade  2004 Outdoor Season   292.971576
# 12th Grade  2004 Outdoor Season   283.626900
# 9th Grade   2004 Outdoor Season   311.133182
# 10th Grade  2005 Outdoor Season   300.080199
# 11th Grade  2005 Outdoor Season   294.732392
# 12th Grade  2005 Outdoor Season   286.553715
# 9th Grade   2005 Outdoor Season   312.206200
# 10th Grade  2006 Outdoor Season   295.622824
# 11th Grade  2006 Outdoor Season   287.365692
# 12th Grade  2006 Outdoor Season   285.456085
# 9th Grade   2006 Outdoor Season   348.526897
# 10th Grade  2007 Outdoor Season   315.651852
# 11th Grade  2007 Outdoor Season   286.646684
# 12th Grade  2007 Outdoor Season   279.505523
# 9th Grade   2007 Outdoor Season   271.560000

# %%
season_sort_min = min_df.groupby(['Grade Level', 'Season']).agg({'1500 Meters': 'min'}).sort_values(by=['Season', 'Grade Level'], ascending = True)
season_sort_min
# Out:
#                                  1500 Meters
# Grade Level Season
# 10th Grade  2004 Outdoor Season       241.73
# 11th Grade  2004 Outdoor Season       235.90
# 12th Grade  2004 Outdoor Season       233.44
# 9th Grade   2004 Outdoor Season       245.33
# 10th Grade  2005 Outdoor Season       242.37
# 11th Grade  2005 Outdoor Season       233.77
# 12th Grade  2005 Outdoor Season       233.03
# 9th Grade   2005 Outdoor Season       249.53
# 10th Grade  2006 Outdoor Season       240.26
# 11th Grade  2006 Outdoor Season       216.00
# 12th Grade  2006 Outdoor Season       229.99
# 9th Grade   2006 Outdoor Season       284.60
# 10th Grade  2007 Outdoor Season       285.50
# 11th Grade  2007 Outdoor Season       239.57
# 12th Grade  2007 Outdoor Season       207.64
# 9th Grade   2007 Outdoor Season       262.10

# %%
season_sort = season_sort.reset_index()

# %%
season_sort_min = season_sort_min.reset_index()

# %%
season_sort.head()
# Out:
#   Grade Level               Season  1500 Meters
# 0  10th Grade  2004 Outdoor Season   298.388028
# 1  11th Grade  2004 Outdoor Season   292.971576
# 2  12th Grade  2004 Outdoor Season   283.626900
# 3   9th Grade  2004 Outdoor Season   311.133182
# 4  10th Grade  2005 Outdoor Season   300.080199

# %%
ax = season_sort.pivot(index='Season', columns='Grade Level', values='1500 Meters').plot(marker='o', figsize=(6,5))

# set the axis labels and title
ax.set_xlabel('Season')
ax.set_title('Average 1500 Meters Times by Season')
ax.set_ylabel('1500 Meter Time (S)')

#add a grid and use margins for x axis
ax.grid(visible=True)
ax.margins(x=0.05)

#change the labels for the x axis
tick_positions = [0, 1, 2, 3]
tick_labels = ['2004', '2005', '2006', '2007']
ax.set_xticks(tick_positions)
ax.set_xticklabels(tick_labels)

#change the legend
ax.legend(['10th', '11th', '12th', '9th'], title='Grade Level')

#change style and show plot
plt.style.use("fivethirtyeight")
plt.show()

# %%
ax = season_sort_min.pivot(index='Season', columns='Grade Level', values='1500 Meters').plot(marker='*',figsize=(6,5))

# set the axis labels and title
ax.set_xlabel('Season')
ax.set_title('Fastest 1500 Meters Times by Season')
ax.set_ylabel('1500 Meter Time (S)')

#add a grid and use margins for x axis
ax.grid(visible=True)
ax.margins(x=0.05)

#change the labels for the x axis
tick_positions = [0, 1, 2, 3]
tick_labels = ['2004', '2005', '2006', '2007']
ax.set_xticks(tick_positions)
ax.set_xticklabels(tick_labels)

#change the legend
ax.legend(['10th', '11th', '12th', '9th'], title='Grade Level')

#change style and show plot
plt.style.use("fivethirtyeight")
plt.show()

# %%
grade_sort = min_df.groupby(['Grade Level', 'Season']).agg({'1500 Meters': 'mean'}).sort_values(by=['Grade Level', 'Season'], ascending = True)
grade_sort
# Out:
#                                  1500 Meters
# Grade Level Season
# 10th Grade  2004 Outdoor Season   298.388028
#             2005 Outdoor Season   300.080199
#             2006 Outdoor Season   295.622824
#             2007 Outdoor Season   315.651852
# 11th Grade  2004 Outdoor Season   292.971576
#             2005 Outdoor Season   294.732392
#             2006 Outdoor Season   287.365692
#             2007 Outdoor Season   286.646684
# 12th Grade  2004 Outdoor Season   283.626900
#             2005 Outdoor Season   286.553715
#             2006 Outdoor Season   285.456085
#             2007 Outdoor Season   279.505523
# 9th Grade   2004 Outdoor Season   311.133182
#             2005 Outdoor Season   312.206200
#             2006 Outdoor Season   348.526897
#             2007 Outdoor Season   271.560000

# %%
grade_sort_min = min_df.groupby(['Grade Level', 'Season']).agg({'1500 Meters': 'min'}).sort_values(by=['Grade Level', 'Season'], ascending = True)
grade_sort_min
# Out:
#                                  1500 Meters
# Grade Level Season
# 10th Grade  2004 Outdoor Season       241.73
#             2005 Outdoor Season       242.37
#             2006 Outdoor Season       240.26
#             2007 Outdoor Season       285.50
# 11th Grade  2004 Outdoor Season       235.90
#             2005 Outdoor Season       233.77
#             2006 Outdoor Season       216.00
#             2007 Outdoor Season       239.57
# 12th Grade  2004 Outdoor Season       233.44
#             2005 Outdoor Season       233.03
#             2006 Outdoor Season       229.99
#             2007 Outdoor Season       207.64
# 9th Grade   2004 Outdoor Season       245.33
#             2005 Outdoor Season       249.53
#             2006 Outdoor Season       284.60
#             2007 Outdoor Season       262.10

# %%
grade_sort = grade_sort.reset_index()

# %%
grade_sort_min = grade_sort_min.reset_index()

# %%
grade_sort = grade_sort.sort_values(by=['Grade Level'], key=lambda x: \
                                    x.map({'9th Grade': 0, '10th Grade': 1, '11th Grade': 2, '12th Grade': 3}))
grade_sort
# Out:
#    Grade Level               Season  1500 Meters
# 12   9th Grade  2004 Outdoor Season   311.133182
# 13   9th Grade  2005 Outdoor Season   312.206200
# 14   9th Grade  2006 Outdoor Season   348.526897
# 15   9th Grade  2007 Outdoor Season   271.560000
# 0   10th Grade  2004 Outdoor Season   298.388028
# 1   10th Grade  2005 Outdoor Season   300.080199
# 2   10th Grade  2006 Outdoor Season   295.622824
# 3   10th Grade  2007 Outdoor Season   315.651852
# 4   11th Grade  2004 Outdoor Season   292.971576
# 5   11th Grade  2005 Outdoor Season   294.732392
# 6   11th Grade  2006 Outdoor Season   287.365692
# 7   11th Grade  2007 Outdoor Season   286.646684
# 8   12th Grade  2004 Outdoor Season   283.626900
# 9   12th Grade  2005 Outdoor Season   286.553715
# 10  12th Grade  2006 Outdoor Season   285.456085
# 11  12th Grade  2007 Outdoor Season   279.505523

# %%
GS = grade_sort.pivot(index='Grade Level', columns='Season', values='1500 Meters').sort_values(by=['Grade Level'], key=lambda x: \
                                    x.map({'9th Grade': 0, '10th Grade': 1, '11th Grade': 2, '12th Grade': 3}))

ax = GS.plot(marker='o',figsize=(6,5))

# set the axis labels and title
ax.set_xlabel('Grade Level')
ax.set_ylabel('1500 Meter Time (S)')
ax.set_title('Average 1500 Meters Times by Grade Level')

#add a grid and use margins for x axis
ax.grid(visible=True)
ax.margins(x=0.05)

#change the labels for the x axis
tick_positions = [0, 1, 2, 3]
tick_labels = ['9th', '10th', '11th', '12th']
ax.set_xticks(tick_positions)
ax.set_xticklabels(tick_labels)

#change the legend
ax.legend(['2004', '2005', '2006', '2007'], title='Grade Level')

#change style and show plot
plt.style.use("fivethirtyeight")
plt.show()

# %%
#create pivot table from the data and map grade level to plot in increase order. 
GS_min = grade_sort_min.pivot(index='Grade Level', columns='Season', values='1500 Meters').sort_values(by=['Grade Level'], key=lambda x: \
                                    x.map({'9th Grade': 0, '10th Grade': 1, '11th Grade': 2, '12th Grade': 3}))

ax = GS_min.plot(marker='o', figsize=(6,5))

# set the axis labels and title
ax.set_xlabel('Grade Level')
ax.set_ylabel('1500 Meter Time (S)')
ax.set_title('Fastest 1500 Meters Times by Grade Level')

#add a grid and use margins for x axis
ax.grid(visible=True)
ax.margins(x=0.05)

#change the labels for the x axis
tick_positions = [0, 1, 2, 3]
tick_labels = ['9th', '10th', '11th', '12th']
ax.set_xticks(tick_positions)
ax.set_xticklabels(tick_labels)

#change the legend
ax.legend(['2004', '2005', '2006', '2007'], title='Outdoor Season')

#change style and show plot
plt.style.use("fivethirtyeight")
plt.show()

# %% [markdown]
# When looking at the mean times per grade level/season we can see that for each of these years, the trend is the same. The mean times are consistenly increasing by grade level. This is what we would expect based on an increase in age, maturity, and likely training.

# %% [markdown]
# Now, when we group and sort by grade level we see that for the years 2004- 2007 there is not much increase as the seasons increase. This shows us that the runners times have a high correlatation with grade level. This makes it easier to assume that athletes in 9th grade will likely run 60.x, etc.

# %%
unique_pop = min_df.groupby(['Season'])['ID Number'].nunique()
unique_pop
# Out:
# Season
# 2004 Outdoor Season     929
# 2005 Outdoor Season    1326
# 2006 Outdoor Season     765
# 2007 Outdoor Season     400
# Name: ID Number, dtype: int64

# %%
#set the color for the axes border
plt.rc('axes',edgecolor='red', linewidth=0.5)

ax = unique_pop.plot(x='Season', y='Count', kind='bar', legend=False, color='lightsteelblue', edgecolor='black', figsize=(6,4))
plt.xlabel('Outdoor Season')
plt.ylabel('Count')
plt.title('1500m Track Participants by Season')

#change the labels for the x axis
tick_positions = [0, 1, 2, 3]
tick_labels = ['2004', '2005', '2006', '2007']
ax.set_xticks(tick_positions)
ax.set_xticklabels(tick_labels)

plt.style.use("fivethirtyeight")
plt.show()

# %% [markdown]
# To answer the population question. I want to know if our sport has been growing as time goes on. This question is hard to answer because of the sparse data. We can see that for the 2004 and 2005 season, there is a clear increase in athletes/season. This shows big growth. For the 2006 season, we can see that the 9th graders are amost absent from the dataset, but the 10th- 12th graders are a little lower than the previous year. The 2007 year is missing most runners in their 9th and 10th grade year. The 11th and 12th graders are between the count from 2004 and 2005.
